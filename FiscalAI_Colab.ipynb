# %% [markdown]
# # 🚀 FiscalAI v2.0 - Auditor Fiscal Inteligente
#
# Sistema de auditoria fiscal com IA, rodando no Google Colab com ngrok.
#
# ## 📋 Passo a Passo:
# 1. Execute as células na ordem
# 2. Configure sua API Key da OpenAI
# 3. Aguarde o link público do ngrok
# 4. Acesse o link e faça upload dos CSVs
# 5. Use o sistema!
#
# ---

# %% [markdown]
# ## 📦 Passo 1: Instalar Dependências

# %%
# !pip install -q fastapi uvicorn[standard] pydantic pydantic-settings python-dotenv
# !pip install -q openai langchain langchain-openai langchain-community
# !pip install -q pandas openpyxl
# !pip install -q pyngrok nest-asyncio

# %% [markdown]
# ## 🔑 Passo 2: Configurar API Keys
#
# ### OpenAI API Key (Obrigatório)
# **IMPORTANTE:** Substitua `sua-api-key-aqui` pela sua chave real da OpenAI!
#
# ### ngrok Authtoken (Obrigatório)
# O ngrok agora requer autenticação. É grátis!
#
# **Como obter:**
# 1. Crie conta gratuita: https://dashboard.ngrok.com/signup
# 2. Copie seu authtoken: https://dashboard.ngrok.com/get-started/your-authtoken
# 3. Cole abaixo no lugar de `seu-ngrok-token-aqui`

# %%
import os

# ⚠️ SUBSTITUA PELAS SUAS CHAVES!

# OpenAI API Key (obrigatório)
os.environ['OPENAI_API_KEY'] = 'sua-api-key-aqui'

# ngrok Authtoken (obrigatório)
os.environ['NGROK_AUTHTOKEN'] = 'seu-ngrok-token-aqui'

# Verificar
if os.environ['OPENAI_API_KEY'] == 'sua-api-key-aqui':
    print('⚠️ ATENÇÃO: Configure sua OpenAI API Key!')
elif os.environ['NGROK_AUTHTOKEN'] == 'seu-ngrok-token-aqui':
    print('⚠️ ATENÇÃO: Configure seu ngrok authtoken!')
else:
    print('✅ API Keys configuradas!')
    print('\n💡 Dicas:')
    print('   • OpenAI cobra por uso (~$0.01-0.10/consulta)')
    print('   • ngrok é grátis para uso básico')
    print('   • Não compartilhe suas chaves!')

# %% [markdown]
# ## 📂 Passo 3: Fazer Upload do Projeto
#
# Faça upload do arquivo `fiscalai-v2.tar.gz` usando o menu lateral do Colab (📁 Files)

# %%
# Extrair projeto
# !tar -xzf fiscalai-v2.tar.gz
# %cd fiscalai-v2

# Verificar estrutura
# !ls -la

# %% [markdown]
# ## 🌐 Passo 4: Iniciar Servidor com ngrok
#
# Esta célula vai:
# 1. Iniciar o servidor FastAPI
# 2. Criar um tunnel ngrok
# 3. Mostrar o link público
#
# **⚠️ IMPORTANTE:** Copie o link que aparecer e cole no navegador!

# %%
# Criar diretório de dados
# !mkdir -p data

# Iniciar aplicação
# !python main.py

# %% [markdown]
# ## 📊 Como Usar o Sistema
#
# ### 1. Acesse o Link Público
# Copie o link do ngrok que apareceu acima (algo como `https://xxxx-xx-xx-xx-xx.ngrok.io`)
#
# ### 2. Faça Upload dos CSVs
# Na página inicial, faça upload de:
# - `202401_NFs_Cabecalho.csv`
# - `202401_NFs_Itens.csv`
# - `CFOP.csv`
#
# ### 3. Inicializar Sistema
# Clique em "Iniciar Processamento"
#
# ### 4. Navegue pelas Funcionalidades
# - 📊 **Estatísticas** - Dashboard com gráficos
# - 💬 **Chat IA** - Faça perguntas sobre as notas
# - ✓ **Validação** - Valide CFOPs específicos
#
# ---
#
# ## 🛑 Para Parar o Servidor
# Clique no botão ⏹️ (Stop) no topo da célula ou use `Runtime > Interrupt execution`
#
# ## 🔄 Para Reiniciar
# Execute novamente a célula "Iniciar Servidor com ngrok"
#
# ---
#
# ## 💡 Dicas
#
# - 🔑 A API Key da OpenAI precisa ter créditos
# - 🌐 O link do ngrok muda cada vez que você reinicia
# - 💾 Os dados são temporários (perdidos ao resetar o Colab)
# - 📱 O sistema funciona em mobile também!
# - ⏱️ Sessões do Colab expiram após inatividade
#
# ## 🆘 Problemas?
#
# **Erro de API Key:**
# - Verifique se configurou corretamente no Passo 2
# - Verifique se tem créditos na conta OpenAI
#
# **Erro ao instalar dependências:**
# - Execute novamente a célula de instalação
# - Reinicie o runtime: `Runtime > Restart runtime`
#
# **ngrok não funciona:**
# - Verifique sua conexão com internet
# - Tente reiniciar a célula do servidor
#
# ---
#
# **FiscalAI v2.0** - Auditoria Fiscal com IA no Google Colab! 🎉
